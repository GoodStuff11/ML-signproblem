# %%
import h5py

folder = r"C:\Users\jonat\Dropbox\programming\cornell courses\research\experimenting\ed\data\N=3.h5"
with h5py.File(folder, "r") as data:
    print(data["E"])
# Out:
# <HDF5 dataset "E": shape (61, 220), type "<f8">

# %%
# Out:
# array([   1,    5,    9, ..., 8837, 8841, 8845], dtype=int64)
